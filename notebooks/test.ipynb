# %%
# %load_ext autoreload
# %autoreload 2

from ews_gis_assets.noe import download_noe_geojson

gdf = download_noe_geojson()

gdf.head(4).T

# %%
gdf.head(4).to_file(
    "noe_windkraftanlagen_sample.geojson",
    driver="GeoJSON",
    # precision=6,
    # metadata={"name": "NOE Windkraftanlagen Sample"},
)
