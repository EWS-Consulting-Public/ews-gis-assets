# %%
# %load_ext autoreload
# %autoreload 2

from ews_gis_assets.noe import download_noe_geojson

gdf = download_noe_geojson()

gdf.head(4).T

# %%
import geopandas as gpd

# Load data directly from GitHub
url = "https://raw.githubusercontent.com/EWS-Consulting-Public/ews-gis-assets/main/data/windkraftanlagen.gpkg"
gdf = gpd.read_file(url)
print(gdf.dtypes)
